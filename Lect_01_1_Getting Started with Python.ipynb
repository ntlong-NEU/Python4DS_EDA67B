# %% [markdown]
# ## Lecture 01: Getting Stared with python and vs code

# %%
print('Hello EDA67B')
# Out:
# Hello EDA67B

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Headers**: Use `#` for headings from level 1 to 6.
# **Bold and Italics**:
# Bold: `**Bold text**`
# talics: `*Italic text*`
# **Lists**:
# Unordered: `- Item`
# Ordered: `1. Item`

# %% [markdown]
# # Heading
# ## Heading
# ### Heading
# #### Heading
# ##### Heading
# ###### Heading

# %% [markdown]
# ## **Heading**

# %% [markdown]
# ### *Heading*
# **Latex**: $x^2+2x+1 = 0$
