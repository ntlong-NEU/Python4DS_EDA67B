# %% [markdown]
# #**I. Multiple Choice**

# %% [markdown]
# **1. Which of the following is the correct way to create an empty dictionary in Python?**
# A. alien_0 = []
# B. alien_0 = ()
# C. alien_0 = {}
# D. alien_0 = ''
#
# **2. What happens when you try to access a non-existent key in a dictionary using square brackets (e.g., print(alien_0['points']))?**
# A. Returns the value None
# B. Returns the value 0
# C. The program raises a KeyError
# D. The program automatically adds the key to the dictionary
#
# **3. Which of the following methods returns a list of all key-value pairs in a dictionary to use in a loop?**
# A. dictionary.keys()
# B. dictionary.value()
# C. dictionary.items()
# D. dictionary.get()
#
# **4. Consider the following code snippet that processes product data:**
# ```
# products = {'p1': {'name': 'Laptop', 'price': 1000}}
# discount = products.get('p2', {}).get('price', 0)
# print(discount)
# ```
# What will be printed to the console?
# A. KeyError: 'p2'
# B. None
# C. 0
# D. {}
#
# **5. How does Python handle the initialization of a dictionary with duplicate keys?**
# ```
# config = {'theme': 'dark', 'version': 1.0, 'theme': 'light'}
# print(config['theme'])
# ```
# A. dark
# B. light
# C. Raises SyntaxError: duplicate key
# D. Returns a list: ['dark', 'light']
#
# **6. The following code iterates directly over the dictionary variable. What does the result variable contain after execution?**
# ```
# prices = {'laptop': 1000, 'mouse': 50}
# result = []
# for item in prices:
#     result.append(item)
# ```
# A. ['laptop', 'mouse']
# B. [1000, 50]
# C. [('laptop', 1000), ('mouse', 50)]
# D. Raises an error due to missing .keys() or .items()
#
# **7. To get a list of unique values (no duplicates) from the `favorite_languages` dictionary, which syntax is correct?**
# A. unique_values(favorite_languages.values())
#
# B. set(favorite_languages.values())
#
# C. list(favorite_languages.values())
#
# D. sorted(favorite_languages.values())
#
# **8. What will happen when the following inventory management code is executed?**
# ```
# inventory = {'apple': 5, 'banana': 2, 'orange': 10}
# for fruit, qty in inventory.items():
#     if qty < 5:
#         del inventory[fruit]
# print(inventory)
# ```
# A. Prints: {'apple': 5, 'orange': 10}
# B. Raises RuntimeError: dictionary changed size during iteration
# C. Raises KeyError: 'banana'
# D. Prints: {'apple': 5, 'banana': 2, 'orange': 10}
#
# **9. When looping through a dictionary's keys, what function can you wrap around the keys() method to get the keys returned in order?**
# A. order()
# B. sort()
# C. alphabetical()
# D. sorted()
#
# **10. JSON structures are often parsed into nested dictionaries. What value does the following code print?**
# ```
# catalog = {
#     'electronics': [{'id': 1, 'name': 'TV'}, {'id': 2, 'name': 'PC'}],
#     'books': [{'id': 3, 'name': 'Python Data'}]
# }
# print(catalog['electronics'][1]['name'])
# ```
# A. 'TV'
# B. 'PC'
# C. 'Python Data'
# D.  KeyError: 1
#
# **11. What does the .replace() method do?**
# ```
# tags = {'post1': 'ecommerce', 'post2': 'erp', 'post3': 'ecommerce'}
# unique_tags = set(tags.values())
# unique_tags.add('erp')
# print(len(unique_tags))
# ```
# A. 2
# B. 3
# C. 4
# D. Raises TypeError
#
# **12. What is the result of the following code?**
# ```
# d = {}
# d['b'] = 2
# d['a'] = 1
# d['c'] = 3
# print(list(d.keys())[0])
# ```
# A. 'a'
# B. 'b'
# C. 'c'
# D. Varies per run (Random)

# %% [markdown]
# **Write your answer here:**
# 1. C
# 2. C
# 3. C
# 4. C
# 5. B
# 6. A
# 7. B
# 8. B
# 9. D
# 10. B
# 11. A
# 12. B

# %% [markdown]
# #**II. Complete Python Code**

# %% [markdown]
# **Question 1**
#
# You are tasked with storing information about a university course. Create a dictionary named `course_info` containing the following details:
#
# - Course name (name): "Python Programming"
# - Number of credits (credits): 3
# - Room: A Tuple containing the building name and room number.
# - After creating the dictionary, print an introductory sentence using the stored information (you must access the elements inside the room Tuple).
#
# **Expected output**: "The Python Programming course ([number of credits]) is held in [building name], [room number]."

# %%
#Write your code here
course_info = {
    'name': "Python Programming",
    'credits': 3,
    'room': ("A2", "101")
}

print(f"The {course_info['name']} course ({course_info['credits']}) is held in {course_info['room'][0]}, {course_info['room'][1]}.")
# Out:
# The Python Programming course (3) is held in A2, 101.

# %% [markdown]
# **Question 2**
# An academic coordinator for an Actuary training program stores student enrollments in a dictionary. The key is the student ID, and the value is a List of modules the student is currently registered for:
# ```
# acturary_enrollments = {
#     'SV01': ['Probability', 'Financial Math', 'Orientation'],
#     'SV02': ['Life Contingencies', 'Orientation'],
#     'SV03': ['Financial Math', 'Statistics', 'Orientation'],
#     'SV04': ['Life Contingencies', 'Statistics']
# }
# ```
# The academic board needs a report of all unique specialized modules currently being taken by students to allocate teaching assistants except `Orientation` from this final list.
# Write a script to extract and print these unique modules.

# %%
#Write your code here
acturary_enrollments = {
    'SV01': ['Probability', 'Financial Math', 'Orientation'],
    'SV02': ['Life Contingencies', 'Orientation'],
    'SV03': ['Financial Math', 'Statistics', 'Orientation'],
    'SV04': ['Life Contingencies', 'Statistics']
}
unique_course = set()
#Cách 1
for course in acturary_enrollments.values():
    if 'Orientation' in course:
      course.remove('Orientation')
      unique_course.update(course)
print("Unique specialized modules:", list(unique_course))

#Cách 2:
for course in acturary_enrollments.values():
  for i in course:
    if i!='Orientation':
      unique_course.add(i)
print("Unique specialized modules:", list(unique_course))

#Cách 3:
for course in acturary_enrollments.values():
    unique_course.update(course)
unique_course.discard('Orientation')
print("Unique specialized modules:", list(unique_course))
# Out:
# Unique specialized modules: ['Life Contingencies', 'Financial Math', 'Statistics', 'Probability']
# Unique specialized modules: ['Life Contingencies', 'Financial Math', 'Statistics', 'Probability']
# Unique specialized modules: ['Life Contingencies', 'Financial Math', 'Statistics', 'Probability']

# %% [markdown]
# **Question 3**
#
# An electronic flight board manages data using a nested dictionary. The primary keys are flight numbers, and the values are dictionaries containing flight details:
# ```
# flights = {
#     'VN123': {'destination': 'Hanoi', 'gate': 'G1', 'status': 'Delayed'},
#     'VJ456': {'destination': 'Danang', 'gate': 'G3', 'status': 'On Time'},
#     'QH789': {'destination': 'Phu Quoc', 'gate': 'G2', 'status': 'Delayed'}
# }
# ```
# Write a script to process the flights dictionary and alert passengers of delays. Your code must:
#
# - Programmatically filter the data to find only the flights that are currently delayed.
#
# - Dynamically extract the flight number, destination, and gate for those specific flights.
# - Print an alert
#
# **Expected output**: "Flight [Flight Number] to [Destination] at gate [Gate] is delayed!"

# %%
#Write your code here
flights = {
    'VN123': {'destination': 'Hanoi', 'gate': 'G1', 'status': 'Delayed'},
    'VJ456': {'destination': 'Danang', 'gate': 'G3', 'status': 'On Time'},
    'QH789': {'destination': 'Phu Quoc', 'gate': 'G2', 'status': 'Delayed'}
}

for flight_num, info in flights.items():
    if info['status'] == 'Delayed':
        print(f"Flight {flight_num} to {info['destination']} at gate {info['gate']} is delayed!")
# Out:
# Flight VN123 to Hanoi at gate G1 is delayed!
# Flight QH789 to Phu Quoc at gate G2 is delayed!

# %% [markdown]
# **Question 4**
#
# A university's legacy registration system exports student course enrollments as a raw list of tuples:
# ```
# raw_enrollment = [
#     ('Alice', 'Math'),
#     ('Bob', 'Physics'),
#     ('Alice', 'Chemistry'),
#     ('Charlie', 'Math'),
#     ('Bob', 'Physics')
# ]
# ```
# Write a script to aggregate this data into a new dictionary where each student's name acts as a key, and their assigned value is a collection of their enrolled courses.
# - Your code must process the data and build the dictionary in a way that automatically eliminates duplicate course registrations for any student.
# - Print the final aggregated dictionary.

# %%
#Write your code here
raw_enrollment = [
    ('Alice', 'Math'),
    ('Bob', 'Physics'),
    ('Alice', 'Chemistry'),
    ('Charlie', 'Math'),
    ('Bob', 'Physics')
]

aggregated_data = {}
for student, course in raw_enrollment:
    if student not in aggregated_data: #Sinh viên chưa có tên trong dictionary
        aggregated_data[student] = set() #Tạo set để lưu sinh viên k bị trùng
    aggregated_data[student].add(course) #Add môn học cho từng sinh viên
print(aggregated_data)
# Out:
# {'Alice': {'Chemistry', 'Math'}, 'Bob': {'Physics'}, 'Charlie': {'Math'}}

# %% [markdown]
# **Question 5**
#
# Given an array of integers `nums` and an integer `target`, find all unique pairs of numbers such that they add up to target.
# ```
# nums = [2, 7, 11, 15, 3, 6, 4, 5]
# target = 9
# ```
# - You cannot use the same element (at the identical index) twice.
# - The final output must contain only unique pairs. For example, (2, 7) and (7, 2) are considered the same pair, so only one should be kept.
# - You must scan the entire list to find all possible solutions.
#
# **Requirement:** Not using function

# %%
#Write your code here
nums = [2, 7, 11, 15, 3, 6, 4, 5]
target = 9

#Cách 1
unique_pair=set()
for i in range(len(nums)):
  for j in range(i+1, len(nums)):
    if nums[i] + nums[j] == target:
      pair = (min(nums[i], nums[j]),max(nums[i], nums[j]))
      unique_pair.add(pair)
print(unique_pair)

#Cách 2
for first_num in nums:
  second_num=target - first_num
  if second_num in nums:
    pair= (min(first_num,second_num),max(first_num,second_num))
    unique_pair.add(pair)
print(unique_pair)
# Out:
# {(4, 5), (2, 7), (3, 6)}
# {(4, 5), (2, 7), (3, 6)}

# %% [markdown]
# **Question 6:**
#
# Roman numerals are represented by seven different symbols: I, V, X, L, C, D and M.
#
# Roman numerals are usually written largest to smallest from left to right. However, if a smaller value appears before a larger value, you subtract it (e.g., IV is 5 - 1 = 4, IX is 10 - 1 = 9).
#
# **Task:** You are given a dictionary:
# ```
# roman_map = {
#     'I': 1, 'V': 5, 'X': 10, 'L': 50,
#     'C': 100, 'D': 500, 'M': 1000
# }
# ```
# You need to convert Roman string `roman="MCMXCIV"` to integers.

# %%
roman_map = {
    'I': 1, 'V': 5, 'X': 10, 'L': 50,
    'C': 100, 'D': 500, 'M': 1000
}
roman="MCMXCIV"
total=0
for i in range(len(roman)): #Lọc qua index của từng phần tử trong dãy roman
  if i < len(roman)-1 and roman_map[roman[i]] < roman_map[roman[i+1]]: #So sánh giá trị đứng trước và đứng sau
    total-=roman_map[roman[i]] #Số này nhỏ hơn số đứng sau nó thì -
  else:
    total+=roman_map[roman[i]] #Số này lớn hơn số đứng sau nó thì +
print(total)
# Out:
# 1994
