# %% [markdown]
# #**Multiple Choice**

# %% [markdown]
# **Question 1. What is the output of the following code?**
# ```python
# queue = [[], [1, 2], []]
# res = 0
# for item in queue:
#     if item:
#         res += sum(item)
#     elif not item:
#         res += 1
# print(res)
# ```
# A. 3
#
# B. 5
#
# C. 4
#
# D. 2
#
#
# **Question 2. What is the output of the following code?**
# ```
# group_a = {"apple", "banana", "cherry"}
# group_b = {"cherry", "date", "apple"}
# result = group_a ^ group_b
# result.update(["banana", "fig"])
# print(len(result))
# ```
# A. 3
#
# B. 2
#
# C. 4
#
# D. 5
#
# **Question 3. Which of the following statements about Sets is FALSE?**
# A. Sets are written with curly brackets {}.
# B. Sets are unordered and unindexed.
# C. You can change existing items in a set using their index.
# D. You can add new items to a set using .add() or .update().
#
# **Question 4. What does the pop() method do when called on a Set?**
#
# A. Removes and returns the last element added to the set.
#
# B. Removes and returns the first element of the set.
#
# C. Removes and returns an arbitrary (random) element because sets are unordered.
#
# D. Removes the maximum value in the set.
#
# **Question 5. Consider a tuple `dimensions = (200, 50)`. Which of the following operations is VALID?**
# A. dimensions[0] = 100
#
# B. dimensions.append(100)
#
# C. dimensions = (800, 600)
#
# D. dimensions.remove(50)
#
# **Question 6. Which set method removes a specified item without raising an error if the item does not exist?**
# A. .remove()
#
# B. .discard()
#
# C. .pop()
#
# D. .clear()
#
# **Question 7. What will be the output of the following code?**
# ```
# numbers = [1, 2, 4, 5]
# for num in numbers:
#     if num == 3:
#         print("Bingo!")
#         break
# else:
#     print("Not found.")
# ```
# A. Bingo!
#
# B. Not found.
#
# C. Bingo! then Not found. on the next line.
#
# D. SyntaxError: 'else' cannot be used with 'for'.
#
# **Question 8. Which of the following code snippets will raise a TypeError?**
#
# A. my_set = {1, 2, (3, 4)}
#
# B. my_set = {1, 2, [3, 4]}
#
# C. my_set = set([1, 2, 3, 3])
#
# D. my_tuple = (1, 2, 3, 4)
#
# **Question 9. What is the output of the following code?**
# ```
# records = [('Alice', 85), ('Bob', 90), ('Alice', 85), ('Charlie', 80)]
# unique_records = set(records)
# print(len(unique_records))
# ```
#
# A. 4
#
# B. 3
#
# C. 2
#
# D. Error: Cannot convert a list of tuples into a set.
#
# **Question 10. Consider the concept of "Deep Mutability". What is the output of this code?**
#
# ```
# data = ([1, 2], 'Python')
# data[0].append(3)
# print(data)
# ```
# A. TypeError: 'tuple' object does not support item assignment
#
# B. ([1, 2], 'Python')
#
# C. ([1, 2, 3], 'Python')
#
# D. [1, 2, 3, 'Python']
#
# **Question 11. How do you correctly combine two sets, set1 and set2, to include all unique items from both?**
#
# A. set1.concat(set2)
#
# B. set1.union(set2)
#
# C. set1.insert(set2)
#
# D. set1.append(set2)
#
# **Question 12. What is the result of the following set comprehension?**
# ```
# A = {1, 2, 3, 4, 5}
# B = {4, 5, 6, 7, 8}
# C = {x for x in (A & B) if x % 2 == 0}
# print(C)
# ```
# A. {4}
#
# B. {4, 5}
#
# C. {2, 4, 6, 8}
#
# D. {5}
#
# **Question 13. What is the output of `text.split('.')[0] + '.'` if `text = "Python is great. It is fast."`?**
#
# A. "Python is great. It is fast."
#
# B. "Python is great."
#
# C. "Python is great"
#
# D. TypeError
#
# **Question 14. Consider two sets A and B. Which comprehension creates a set C containing items present in BOTH A and B, but ONLY if the item is divisible by 4?**
# A. C = {x for x in (A or B) if x % 4 == 0}
#
# B. C = {x for x in (A & B) if x % 4 == 0}
#
# C. C = {x for x in (A + B) if x / 4 == 0}
#
# D. C = {x for x in (A|B) if x % 4 == 0}
#
# **Question 15. If multiple conditions evaluate to True in an if-elif-else chain, which blocks execute?**
#
#
# A. Only the final else block.
#
# B. All of the true blocks.
#
# C. Only the last true block.
#
# D.Only the first true block.
#
# **Question 16. Which specific operator determines if a targeted value does NOT appear inside a list?**
#
# A. not in
#
# B. absent
#
# C. not =
#
# D. out of
#
# **Question 17. In an if-elif-else chain, under what circumstances does the elif block evaluate its condition?**
#
#
# A. Regardless of the preceding tests.
#
# B. Only if the else block is empty.
#
# C. Only if the preceding test passes.
#
# D. Only if the preceding test fails.

# %% [markdown]
# **Write your answer here:**
# 1.  B
# 2.  A
# 3.  C
# 4.  C
# 5.  C
# 6.  B
# 7.  B
# 8.  B
# 9.  B
# 10. C
# 11. B
# 12. A
# 13. B
# 14. B
# 15. D
# 16. A
# 17. D

# %% [markdown]
# #**II. Complete Python Code**

# %% [markdown]
# **Question 1.** A "Pangram" is a sentence that uses every single letter of the English alphabet at least once. You are given a sentence:
# ```
# Sentence = "Pack my box with five dozen liquor jugs"
# ```
# Write a script to verify if the sentence is a pangram.
#
# - Replace all space characters in the sentence with an empty string.
#
# - Convert the modified string into a Set of characters.
#
# - Calculate the total number of unique letters in that Set.
#
# - Use the equality operator to check if the length equals 26, and directly print the resulting boolean value.

# %%
#Write your code here
sentence = "Pack my box with five dozen liquor jugs"
Sentence=sentence.lower().replace(" ","")
print(Sentence)
unique_count= set(Sentence)
print(len(unique_count) == 26)
# Out:
# packmyboxwithfivedozenliquorjugs
# True

# %% [markdown]
# **Question 2. A coding bootcamp runs for 3 days. You are given 3 lists containing the names of students who attended each day.**
# ```
# day1 = ["Alice", "Bob", "Charlie", "David"]
# day2 = ["Bob", "David", "Eve", "Frank"]
# day3 = ["Alice", "Bob", "David", "George"]
# ```
# Write a script to:
#
# - Convert all three lists into sets.
#
# - Use Set operations to find and print a set of students who have "Perfect Attendance" (attended all 3 days).
#
# - Use Set operations to find and print a set of students who attended at least one day across the entire bootcamp.

# %%
#Write your code here
day1 = ["Alice", "Bob", "Charlie", "David"]
day2 = ["Bob", "David", "Eve", "Frank"]
day3 = ["Alice", "Bob", "David", "George"]
set1 = set(day1)
set2 = set(day2)
set3 = set(day3)
Perfect = set1.intersection(set2).intersection(set3)
print(f"Perfect Attendance: {Perfect}")
Attended = set1.union(set2).union(set3)
print(f"Students who are attended: {Attended}")
# Out:
# Perfect Attendance: {'Bob', 'David'}
# Students who are attended: {'George', 'Bob', 'Alice', 'David', 'Frank', 'Eve', 'Charlie'}

# %% [markdown]
# **Question 3. Given a list of daily sales records. Each record is a tuple containing `(Customer_Name, Quantity, Price_Per_Unit)`. However, the customer names were entered carelessly with random extra spaces and mixed uppercase/lowercase letters.**
#
# ```
# sales_data = [
#     ("  aLice ", 2, 120),
#     ("BOB", 1, 300),
#     (" alice", 1, 120),
#     ("CHARLIE  ", 4, 25),
#     (" bob ", 2, 300)
# ]
# ```
# Using a for loop to iterate through the sales_data list, write a Python script to calculate and print exactly two things:
#
# 1. The Grand Total Revenue generated from all sales.
#
# 2. The exact number of unique customers who made a purchase. You MUST use a Set to store the cleaned names to automatically handle duplicates (e.g., "  aLice " and " alice" must be recognized as the exact same person).

# %%
sales_data = [
    ("  aLice ", 2, 120),
    ("BOB", 1, 300),
    (" alice", 1, 120),
    ("CHARLIE  ", 4, 25),
    (" bob ", 2, 300)
]
unique_cus = set()
total_rev = 0
for name, qty, price in sales_data:
  rev = qty*price
  total_rev += rev
  uni_cus = name.lower().strip()
  unique_cus.add(uni_cus)
print(f'Grand Total Rev: {total_rev}')
print('Number of customers:', len(unique_cus))
# Out:
# Grand Total Rev: 1360
# Number of customers: 3

# %% [markdown]
# **Exercise 4. You are analyzing customer reviews for a new smartphone. You have two reviews:**
# ```
# review1 = "The battery is great and the screen is amazing"
# review2 = "The battery is terrible and the price is high"
# ```
#
# Write a script to extract the meaningful keywords from these reviews. Perform the following steps sequentially:
#
# - Convert both strings to lowercase. Use a string method to split them into lists of words, then turn those lists into two separate Sets of words.
#
# - In text analysis, we ignore common words. Create a set named `stop_words` containing exactly these three words: {"the", "is", "and"}.
#
# - Use a Set operation to find the words that appear in **Both** reviews. Then, use another Set operation to mathematically remove the `stop_words` from this result. Store the final set in a variable `shared_keywords`.
#
# - Use a Set operation to find the contrasting words—words that appear in **Only one** of the reviews (Symmetric Difference). Remove the stop_words from this result as well. Store it in a variable `contrasting_keywords`.
#
# - Convert both resulting sets into sorted lists and print them.

# %%
review1 = "The battery is great and the screen is amazing"
review2 = "The battery is terrible and the price is high"
rev1 = set(review1.lower().split())
rev2 = set(review2.lower().split())
stop_words = {"the","is","and"}
shared_keywords = (rev1 & rev2) - stop_words
contrasting_keywords = (rev1^rev2)- stop_words
print("Shared keywords:", sorted(shared_keywords))
print("Contrasting keywords:", sorted(contrasting_keywords))
# Out:
# Shared keywords: ['battery']
# Contrasting keywords: ['amazing', 'great', 'high', 'price', 'screen', 'terrible']

# %% [markdown]
# **Question 5. Given a matrix (a list of sublists) representing the students' scores in a class.
# Each sublist represents a student's scores for different subjects.**
# ```
# students = [
#     'John Smith', 'Emily Johnson', 'Michael Williams', 'Jessica Brown',
#     'David Jones', 'Sophia Davis', 'Daniel Martinez', 'Olivia Miller',
#     'James Wilson', 'Emma Taylor'
# ]
#
# scores = [
#     [85, 78, 92, 88, 76, 90, 87, 89],
#     [92, 86, 78, 94, 89, 91, 85, 82],
#     [75, 80, 88, 84, 79, 92, 86, 90],
#     [89, 92, 75, 81, 87, 79, 84, 88],
#     [78, 81, 89, 93, 85, 90, 88, 82],
#     [92, 85, 78, 90, 83, 89, 87, 91],
#     [86, 91, 75, 80, 88, 84, 82, 89],
#     [78, 84, 89, 92, 86, 91, 83, 80],
#     [90, 88, 82, 79, 91, 76, 83, 85],
#     [87, 80, 91, 85, 78, 92, 89, 84]
# ]
# ```

# %% [markdown]
# 1. The school database requires the students' first and last names to be separated and stored as unchangeable records.
#
# - Write a Python script that uses a for loop to process the students list.
# - For each student, separate their first name and last name, and pack them into a Tuple.
# - Gather all these tuples into a newly created list called `split_names`.
# - Print the `split_names` list.

# %%
students = [
    'John Smith', 'Emily Johnson', 'Michael Williams', 'Jessica Brown',
    'David Jones', 'Sophia Davis', 'Daniel Martinez', 'Olivia Miller',
    'James Wilson', 'Emma Taylor'
]
split_names = []
for stu in students:
  student=stu.split(' ',1)
  first_name=student[0]
  last_name=student[1]
  split_names.append((first_name,last_name))
print(split_names)
# Out:
# [('John', 'Smith'), ('Emily', 'Johnson'), ('Michael', 'Williams'), ('Jessica', 'Brown'), ('David', 'Jones'), ('Sophia', 'Davis'), ('Daniel', 'Martinez'), ('Olivia', 'Miller'), ('James', 'Wilson'), ('Emma', 'Taylor')]

# %% [markdown]
# 2. The teacher wants to know exactly how many **different** unique score values were given out across the entire class, completely ignoring who got what.
#
# - Using a nested for loop, iterate through every single numerical score inside the `scores` matrix.
# - Extract these scores into a specific data structure that automatically ignores and filters out duplicates.
# - Calculate and print the total number of unique scores found.

# %%
scores = [
    [85, 78, 92, 88, 76, 90, 87, 89],
    [92, 86, 78, 94, 89, 91, 85, 82],
    [75, 80, 88, 84, 79, 92, 86, 90],
    [89, 92, 75, 81, 87, 79, 84, 88],
    [78, 81, 89, 93, 85, 90, 88, 82],
    [92, 85, 78, 90, 83, 89, 87, 91],
    [86, 91, 75, 80, 88, 84, 82, 89],
    [78, 84, 89, 92, 86, 91, 83, 80],
    [90, 88, 82, 79, 91, 76, 83, 85],
    [87, 80, 91, 85, 78, 92, 89, 84]
]
uni_scores = set()
for i in scores:
    uni_scores.update(i)
print(uni_scores)
print(len(uni_scores))
# Out:
# {75, 76, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, 93, 94}
# 19

# %% [markdown]
# **Question 6.** A library only has specific book titles available. When a student submits a list of books they want to borrow, the system must check if each book is currently in stock.
#
# 1. Create a list called `available_books` containing 'Math', 'Literature', 'Physics', 'History', 'Science'.
#
# 2. Create a second list called `requested_books` containing 'English', 'Math', 'Geography'.
#
# 3. Write a for loop to iterate through each book in the `requested_books` list and check if the requested book exists in `available_books`.
#
# 4. If it is available, print "Successfully borrowed [book_name].".  If it is not available, print "Sorry, the library does not have [book_name] right now.".

# %%
#Write your code here
available_books=['Math', 'Literature', 'Physics', 'History', 'Science']
requested_books=['English', 'Math', 'Geography']
for i in requested_books:
  if i in available_books:
    print(f"Successfully borrowed {i}")
  else:
    print(f"Sorry, the library does not have {i}")
# Out:
# Sorry, the library does not have English
# Successfully borrowed Math
# Sorry, the library does not have Geography

# %% [markdown]
# **Question 7.** To optimize efficiency, a warehouse manager only inspects a specific subset of inventory bins rather than the entire floor.
# ```
# stock = [15, 2, 8, 0, 12, 5, 20, 1, 9]
# ````
# - Only process stock quantities that are odd numbers.
#
# - If the stock is empty, print "CRITICAL: Item out of stock!" and add 2 to the restock count.
#
# - If the stock is less than 5, print "Warning: Low stock." and add 1 to the restock count.
#
# - Otherwise, print "Stock level is stable."
#
# - Finally, print the total restock count.

# %%
#Write your code here
stock = [15, 2, 8, 0, 12, 5, 20, 1, 9]
restock_count = 0

for item in stock:
    if item % 2 != 0 or item == 0:
        if item == 0:
            print("CRITICAL: Item out of stock!")
            restock_count += 2
        elif item < 5:
            print("Warning: Low stock.")
            restock_count += 1
        else:
            print("Stock level is stable.")
print("Total restock count:", restock_count)
# Out:
# Stock level is stable.
# CRITICAL: Item out of stock!
# Stock level is stable.
# ...
# Stock level is stable.
# Total restock count: 3

# %% [markdown]
# **Question 7.** To optimize efficiency, a warehouse manager only inspects a specific subset of inventory bins rather than the entire floor.
# ```
# stock = [15, 2, 8, 0, 12, 5, 20, 1, 9]
# ````
# - Only process stock quantities that are odd numbers.
#
# - If the stock is empty, print "CRITICAL: Item out of stock!" and add 2 to the restock count.
#
# - If the stock is less than 5, print "Warning: Low stock." and add 1 to the restock count.
#
# - Otherwise, print "Stock level is stable."
#
# - Finally, print the total restock count.

# %% [markdown]
# **Question 8.** You are processing a main list called daily_batches.
# ```
# daily_batches = [ [], ["Data1", "Data2"], [None, ""], ["Data3"], [] ]
# ```
# - Extract valid data from `daily_batches` into a single new list.
# - If a batch has zero items initially, print "Skipping empty batch."
# - Otherwise, filter out any invalid items (None and "").
# - After filtering, if the batch contains no valid items, print "Batch dropped."
# - If the batch still has valid items, add them to your new list and print "Processed valid batch."
# - Print the final list of valid data.

# %%
#Write your code here
daily_batches = [ [], ["Data1", "Data2"], [None, ""], ["Data3"], [] ]
newl=[]
for i in daily_batches:
  if not i:
    print('Skipping empty batch')
    continue
  else:
    filtered=[item for item in i if item not in ('',None)]
    if len(filtered)==0:
      print('Batch dropped')
      continue
    else:
      print('Processed valid batch')
      newl.extend(filtered)
print(newl)
# Out:
# Skipping empty batch
# Processed valid batch
# Batch dropped
# Processed valid batch
# Skipping empty batch
# ['Data1', 'Data2', 'Data3']

# %% [markdown]
# **Question 9. You are given a list of tuples representing students and their scores:**
# ```
# data = [('Alice', 19), ('Bob', 60), ('Charlie', 100), ('David', 96), ('Emma', 84),
#  ('Frank', 99), ('Grace', 76), ('Hannah', 59), ('Isaac', 96), ('Jack', 39),
#  ('Katie', 93), ('Liam', 73), ('Mia', 58), ('Noah', 73), ('Olivia', 95),
#  ('Peter', 78), ('Quinn', 21), ('Rachel', 10), ('Samuel', 17), ('Taylor', 89)]
# ```

# %% [markdown]
# Without using the built-in max() function, write a Python script using a for loop to find and print the name of the person with the highest score and their score.

# %%
#Write your code here
data = [
    ('Alice', 19), ('Bob', 60), ('Charlie', 100), ('David', 96),
    ('Emma', 84), ('Frank', 99), ('Grace', 76), ('Hannah', 59),
    ('Isaac', 96), ('Jack', 39), ('Katie', 93), ('Liam', 73),
    ('Mia', 58), ('Noah', 73), ('Olivia', 95), ('Peter', 78),
    ('Quinn', 21), ('Rachel', 10), ('Samuel', 17), ('Taylor', 89)
]
highest_score = 0
best_student = ""
for name, score in data:
    if score > highest_score:
        highest_score = score
        best_student = name

print(best_student, highest_score)
# Out:
# Charlie 100

# %% [markdown]
# **Exercise 10: (Optional)** Split a paragraph of text into smaller paragraphs less than number_char = 45 characters in size and rejoin paragraphs by "\n\n".
# - The cutting point should be at the end of the sentence, except if not possible, leave it in the space position.
# - Using for loop and if - elif - else
#
# **Input**: "Coding is more than just typing syntax. It builds logic and problem-solving skills. Stay patient and keep practicing every day!“
#
# *Note: You can write your idea instead of code*

# %% [markdown]
# **Luồng logic**
#
# Khi ta duyệt qua từng từ (word) trong danh sách các từ:
#
# - Case 1: If the current line is empty (not line) -> Assign the word directly to the line: line = word. If it contains a punctuation mark, add this line to the paragraphs -> start a new line.
#
# - Case 2: If appending this word exceeds the 45-character limit -> It can no longer be appended. Save the old line into the paragraphs, and use the current word to start a new line: line = word.
#
# - Case : If there is still space (under 45 characters) and it ends with a punctuation mark -> Append the word to the current line: line += " " + word -> add the line to the paragraphs -> start a new line.
#
# - Case 4: If there is still space (under 45 characters) and it does not end with a punctuation mark -> line += " " + word.
#
# - If the line is not empty -> add the remaining line to the paragraphs.
#
# - Join the paragraphs together.

# %%
text = "Coding is more than just typing syntax. It builds logic and problem-solving skills. Stay patient and keep practicing every day!"
words = text.split()
paragraphs = []
line = ""

for word in words:
    if not line:
        line = word
        if "." in word or "!" in word:
          paragraphs.append(line)
          line=""
    elif len(line + " " + word) > 45:
        paragraphs.append(line)
        line = word
    elif "." in word or "!" in word:
      line=line+ " "+word
      paragraphs.append(line)
      line=""
    else:
      line += " " + word
if line:
    paragraphs.append(line)
result = "\n\n".join(paragraphs)
print(result)
# Out:
# Coding is more than just typing syntax.
#
# It builds logic and problem-solving skills.
#
# Stay patient and keep practicing every day!
